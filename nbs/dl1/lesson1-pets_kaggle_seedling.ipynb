# %% [markdown]
# # Lesson 1 - What's your pet

# %% [markdown]
# Welcome to lesson 1! For those of you who are using a Jupyter Notebook for the first time, you can learn about this useful tool in a tutorial we prepared specially for you; click `File`->`Open` now and click `00_notebook_tutorial.ipynb`.
#
# In this lesson we will build our first image classifier from scratch, and see if we can achieve world-class results. Let's dive in!
#
# Every notebook starts with the following three lines; they ensure that any edits to libraries you make are reloaded here automatically, and also that any charts or images displayed are shown in this notebook.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.0](https://hackernoon.com/pytorch-1-0-468332ba5163). The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models.

# %%
from fastai.vision import *

# %% [markdown]
# If you're using a computer with an unusually small GPU, you may get an out of memory error when running this notebook. If this happens, click Kernel->Restart, uncomment the 2nd line below to use a smaller *batch size* (you'll learn all about what this means during the course), and try again.

# %%
bs = 64
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# ## Get data from kaggle seedling playground

# %%
# !mkdir -p ~/.kaggle/
# !echo '{"username":"ohliumliu","key":"64d6235a5b894aa080ae786d63020c46"}' > ~/.kaggle/kaggle.json
# !cat ~/.kaggle/kaggle.json

# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# {"username":"ohliumliu","key":"64d6235a5b894aa080ae786d63020c46"}

# %%
# !kaggle competitions download -c plant-seedlings-classification
# Out:
# ...
#   0%|                                               | 0.00/5.13k [00:00<?, ?B/s]
# 100%|██████████████████████████████████████| 5.13k/5.13k [00:00<00:00, 4.46MB/s]
# ...
#  94%|███████████████████████████████████▊  | 81.0M/86.0M [00:02<00:00, 30.0MB/s]
# 100%|██████████████████████████████████████| 86.0M/86.0M [00:02<00:00, 34.7MB/s]
# ...
# 100%|█████████████████████████████████████▊| 1.59G/1.60G [00:24<00:00, 82.7MB/s]
# 100%|██████████████████████████████████████| 1.60G/1.60G [00:24<00:00, 70.1MB/s]

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# We are going to use the [Oxford-IIIT Pet Dataset](http://www.robots.ox.ac.uk/~vgg/data/pets/) by [O. M. Parkhi et al., 2012](http://www.robots.ox.ac.uk/~vgg/publications/2012/parkhi12a/parkhi12a.pdf) which features 12 cat breeds and 25 dogs breeds. Our model will need to learn to differentiate between these 37 distinct categories. According to their paper, the best accuracy they could get in 2012 was 59.21%, using a complex model that was specific to pet detection, with separate "Image", "Head", and "Body" models for the pet photos. Let's see how accurate we can be using deep learning!
#
# We are going to use the `untar_data` function to which we must pass a URL as an argument and which will download and extract the data.

# %%
path = Path('/home/jupyter/tutorials/fastai/course-v3/nbs/dl1/kaggle-seedlings/')

# %%
path.ls()
# Out:
# [PosixPath('/home/jupyter/tutorials/fastai/course-v3/nbs/dl1/kaggle-seedlings/sample_submission.csv'),
#  PosixPath('/home/jupyter/tutorials/fastai/course-v3/nbs/dl1/kaggle-seedlings/sample_submission.csv.zip'),
#  PosixPath('/home/jupyter/tutorials/fastai/course-v3/nbs/dl1/kaggle-seedlings/learn50_pred.txt'),
#  PosixPath('/home/jupyter/tutorials/fastai/course-v3/nbs/dl1/kaggle-seedlings/models'),
#  PosixPath('/home/jupyter/tutorials/fastai/course-v3/nbs/dl1/kaggle-seedlings/train'),
#  PosixPath('/home/jupyter/tutorials/fastai/course-v3/nbs/dl1/kaggle-seedlings/test'),
#  PosixPath('/home/jupyter/tutorials/fastai/course-v3/nbs/dl1/kaggle-seedlings/test.zip'),
#  PosixPath('/home/jupyter/tutorials/fastai/course-v3/nbs/dl1/kaggle-seedlings/valid')]

# %%
path_img = path/'train'

# %% [markdown]
# The first thing we do when we approach a problem is to take a look at the data. We _always_ need to understand very well what the problem is and what the data looks like before we can figure out how to solve it. Taking a look at the data means understanding how the data directories are structured, what the labels are and what some sample images look like.
#
# The main difference between the handling of image classification datasets is the way labels are stored. In this particular dataset, labels are stored in the filenames themselves. We will need to extract them to be able to classify the images into the correct categories. Fortunately, the fastai library has a handy function made exactly for this, `ImageDataBunch.from_name_re` gets the labels from the filenames using a [regular expression](https://docs.python.org/3.6/library/re.html).

# %%
fnames_bg = get_image_files(path_img/'Black-grass')
fnames_ls = get_image_files(path_img/'Loose Silky-bent')

# %%
plt.imshow(plt.imread(str(fnames_bg[3])))

# %%
plt.imshow(plt.imread(str(fnames_ls[3])))

# %%
get_transforms?

# %%
# this works
data = ImageDataBunch.from_folder(path=path_img, valid_pct=0.2, ds_tfms=get_transforms(do_flip=False), bs=bs, size=229).normalize(imagenet_stats)

# %%
# this can include the test set
data2 = ImageDataBunch.from_folder(path=path_img, 
                                   test='../test',
                                   valid_pct=0.2, 
                                   ds_tfms=get_transforms(), bs=bs, size=229).normalize(imagenet_stats)

# %%
data2.classes
# Out:
# ['Black-grass',
#  'Charlock',
#  'Cleavers',
#  'Common Chickweed',
#  'Common wheat',
#  'Fat Hen',
#  'Loose Silky-bent',
#  'Maize',
#  'Scentless Mayweed',
#  'Shepherds Purse',
#  'Small-flowered Cranesbill',
#  'Sugar beet']

# %%
# this can include the test sets, but also adds a class 'test'. so only do this after the model is trained.
data = ImageDataBunch.from_folder(path=path, valid_pct=0.2, test='./test', ds_tfms=get_transforms(do_flip=False), bs=bs, size=229).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['Black-grass',
#  'Charlock',
#  'Cleavers',
#  'Common Chickweed',
#  'Common wheat',
#  'Fat Hen',
#  'Loose Silky-bent',
#  'Maize',
#  'Scentless Mayweed',
#  'Shepherds Purse',
#  'Small-flowered Cranesbill',
#  'Sugar beet',
#  'test']

# %%
data2.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Black-grass', 'Charlock', 'Cleavers', 'Common Chickweed', 'Common wheat', 'Fat Hen', 'Loose Silky-bent', 'Maize', 'Scentless Mayweed', 'Shepherds Purse', 'Small-flowered Cranesbill', 'Sugar beet']
# (12, 12)

# %% [markdown]
# ## Training: resnet34

# %% [markdown]
# Now we will start training our model. We will use a [convolutional neural network](http://cs231n.github.io/convolutional-networks/) backbone and a fully connected head with a single hidden layer as a classifier. Don't know what these things mean? Not to worry, we will dive deeper in the coming lessons. For the moment you need to know that we are building a model which will take images as input and will output the predicted probability for each of the categories (in this case, it will have 37 outputs).
#
# We will train for 4 epochs (4 cycles through all our data).

# %%
learn = create_cnn(data2, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(8)
# Out:
# Total time: 03:45 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>2.213911</th>
#     <th>1.279960</th>
#     <th>0.424211</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.324811</th>
#     <th>0.596738</th>
#     <th>0.197895</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.862586</th>
#     <th>0.401995</th>
#     <th>0.136842</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.605081</th>
#     <th>0.305587</th>
#     <th>0.122105</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.455558</th>
#     <th>0.270096</th>
#     <th>0.105263</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.380381</th>
#     <th>0.250940</th>
#     <th>0.095789</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.333893</th>
#     <th>0.232744</th>
#     <th>0.089474</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.322907</th>
# ...

# %%
learn.recorder.plot_losses()

# %%
learn.save('seedling_resnet34_simple') # after 8 cycles, error rate = 0.087, 20190116

# %% [markdown]
# ## Results

# %% [markdown]
# Let's see what results we have got.
#
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.pred_class?

# %%
interp.plot_confusion_matrix(figsize=(12, 12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Black-grass', 'Loose Silky-bent', 30),
#  ('Loose Silky-bent', 'Black-grass', 6),
#  ('Scentless Mayweed', 'Common Chickweed', 4),
#  ('Scentless Mayweed', 'Shepherds Purse', 4),
#  ('Black-grass', 'Common wheat', 3),
#  ('Fat Hen', 'Common Chickweed', 3),
#  ('Loose Silky-bent', 'Scentless Mayweed', 3),
#  ('Shepherds Purse', 'Small-flowered Cranesbill', 3)]

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:34 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.384209</th>
#     <th>0.229605</th>
#     <th>0.077895</th>
#   </tr>
# </table>

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(6, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 03:21 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.293443</th>
#     <th>0.222270</th>
#     <th>0.087368</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.268143</th>
#     <th>0.204810</th>
#     <th>0.070526</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.252970</th>
#     <th>0.185567</th>
#     <th>0.066316</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.225974</th>
#     <th>0.176684</th>
#     <th>0.063158</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.208083</th>
#     <th>0.172251</th>
#     <th>0.060000</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.203446</th>
#     <th>0.173193</th>
#     <th>0.058947</th>
#   </tr>
# </table>

# %%
learn.fit_one_cycle(10, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 05:34 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.193624</th>
#     <th>0.171123</th>
#     <th>0.060000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.192996</th>
#     <th>0.167894</th>
#     <th>0.062105</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.179595</th>
#     <th>0.159555</th>
#     <th>0.055789</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.164524</th>
#     <th>0.148602</th>
#     <th>0.049474</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.156008</th>
#     <th>0.144650</th>
#     <th>0.044211</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.149525</th>
#     <th>0.142647</th>
#     <th>0.046316</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.132462</th>
#     <th>0.141198</th>
#     <th>0.046316</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.124633</th>
# ...

# %%
learn.recorder.plot_losses()

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. It will be explained later in the course and you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us use larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network will require more GPU memory.

# %%
learn50 = create_cnn(data2, models.resnet50, metrics=error_rate)

# %%
learn50.lr_find()
learn50.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn50.fit_one_cycle(8)
# Out:
# Total time: 06:27 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.707459</th>
#     <th>0.804173</th>
#     <th>0.251579</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.998500</th>
#     <th>0.477097</th>
#     <th>0.168421</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.602611</th>
#     <th>0.308302</th>
#     <th>0.106316</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.410271</th>
#     <th>0.238508</th>
#     <th>0.084211</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.309309</th>
#     <th>0.194561</th>
#     <th>0.058947</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.247322</th>
#     <th>0.188097</th>
#     <th>0.068421</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.204026</th>
#     <th>0.170986</th>
#     <th>0.057895</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.180047</th>
# ...

# %% [markdown]
# Without unfreezing, the lowest error rate is about 0.054.

# %%
learn50.save('seedling-resnet50-simple')

# %% [markdown]
# It's astonishing that it's possible to recognize pet breeds so accurately! Let's see if full fine-tuning helps:

# %%
learn50.unfreeze()
learn50.fit_one_cycle(3, max_lr=slice(1e-5,1e-3))
# Out:
# Total time: 03:02 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.793585</th>
#     <th>6.724698</th>
#     <th>0.641053</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.577389</th>
#     <th>0.601071</th>
#     <th>0.213684</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.325903</th>
#     <th>0.152062</th>
#     <th>0.058947</th>
#   </tr>
# </table>

# %%
learn50.fit_one_cycle(3, max_lr=slice(1e-5,1e-3))
# Out:
# Total time: 03:02 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.198154</th>
#     <th>0.144861</th>
#     <th>0.046316</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.187916</th>
#     <th>0.134481</th>
#     <th>0.043158</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.170750</th>
#     <th>0.133979</th>
#     <th>0.045263</th>
#   </tr>
# </table>

# %%
learn50.save('seedling_resnet50-unfreeze');

# %%
interp = ClassificationInterpretation.from_learner(learn50)

# %%
interp.plot_top_losses(5)

# %%
interp.plot_confusion_matrix(figsize=(12, 12))

# %%
learn50.load('seedling_resnet50-unfreeze')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList
# y: CategoryList (3800 items)
# [Category Shepherds Purse, Category Shepherds Purse, Category Shepherds Purse, Category Shepherds Purse, Category Shepherds Purse]...
# Path: /home/jupyter/tutorials/fastai/course-v3/nbs/dl1/kaggle-seedlings/train
# x: ImageItemList (3800 items)
# [Image (3, 374, 374), Image (3, 101, 101), Image (3, 501, 501), Image (3, 176, 176), Image (3, 349, 349)]...
# Path: /home/jupyter/tutorials/fastai/course-v3/nbs/dl1/kaggle-seedlings/train;
#
# Valid: LabelList
# y: CategoryList (950 items)
# [Category Shepherds Purse, Category Maize, Category Loose Silky-bent, Category Loose Silky-bent, Category Common Chickweed]...
# Path: /home/jupyter/tutorials/fastai/course-v3/nbs/dl1/kaggle-seedlings/train
# x: ImageItemList (950 items)
# [Image (3, 266, 266), Image (3, 546, 546), Image (3, 416, 416), Image (3, 115, 115), Image (3, 446, 446)]...
# ...

# %%
preds_test_TTA, y = learn50.TTA(ds_type=DatasetType.Test)
# Out:
# Total time: 00:39 <p>

# %%
preds, y = learn50.get_preds(ds_type=DatasetType.Test)

# %%
seedling_pred = np.argmax(preds, 1)
seedling_pred_TTA = np.argmax(preds_test_TTA, 1)

# %%
submission = pd.DataFrame({'file': os.listdir(path/'test'), 'species': [data2.classes[s] for s in seedling_pred_TTA]})
submission.head()
# Out:
#             file            species
# 0  d84d37a61.png   Common Chickweed
# 1  04814f36d.png  Scentless Mayweed
# 2  b39c71707.png              Maize
# 3  604dd663f.png    Shepherds Purse
# 4  5b63dcc21.png   Common Chickweed

# %%
submission.to_csv('pred_unfreeze.txt', index = False)

# %%
os.listdir()
# Out:
# ['sample_submission.csv',
#  'sample_submission.csv.zip',
#  'learn50_pred.txt',
#  'models',
#  'pred_unfreeze.txt',
#  'train',
#  'pred.txt',
#  'test',
#  'test.zip',
#  'valid']

# %%
# !kaggle competitions submit -c plant-seedlings-classification -f pred_unfreeze.txt -m "learn50 unfreeze"
# Out:
# 100%|██████████████████████████████████████| 22.3k/22.3k [00:00<00:00, 28.7kB/s]
# Successfully submitted to Plant Seedlings Classification

# %% [markdown]
# ## Other data formats

# %%
ImageDataBunch.from_name_re?

# %%
path = untar_data(URLs.MNIST_SAMPLE); path
# Out:
# PosixPath('/home/jupyter/.fastai/data/mnist_sample')

# %%
tfms = get_transforms(do_flip=False)
data = ImageDataBunch.from_folder(path, ds_tfms=tfms, size=26)

# %%
len(data.valid_ds)
# Out:
# 2038

# %%
data.show_batch(rows=3, figsize=(5,5))

# %%
learn.fit??

# %%
learn = create_cnn(data, models.resnet18, metrics=accuracy)
learn.fit(2)
# Out:
# Total time: 00:10 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.193257</th>
#     <th>0.064896</th>
#     <th>0.980864</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.114230</th>
#     <th>0.032311</th>
#     <th>0.991168</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_lr()

# %%
df = pd.read_csv(path/'labels.csv')
df.head()
# Out:
#                 name  label
# 0   train/3/7463.png      0
# 1  train/3/21102.png      0
# 2  train/3/31559.png      0
# 3  train/3/46882.png      0
# 4  train/3/26209.png      0

# %%
data = ImageDataBunch.from_csv(path, ds_tfms=tfms, size=28)

# %%
data.show_batch(rows=3, figsize=(5,5))
data.classes
# Out:
# [0, 1]

# %%
data = ImageDataBunch.from_df(path, df, ds_tfms=tfms, size=24)
data.classes
# Out:
# [0, 1]

# %%
fn_paths = [path/name for name in df['name']]; fn_paths[:2]
# Out:
# [PosixPath('/home/jupyter/.fastai/data/mnist_sample/train/3/7463.png'),
#  PosixPath('/home/jupyter/.fastai/data/mnist_sample/train/3/21102.png')]

# %%
pat = r"/(\d)/\d+\.png$"
data = ImageDataBunch.from_name_re(path, fn_paths, pat=pat, ds_tfms=tfms, size=24)
data.classes
# Out:
# ['3', '7']

# %%
data = ImageDataBunch.from_name_func(path, fn_paths, ds_tfms=tfms, size=24,
        label_func = lambda x: '3' if '/3/' in str(x) else '7')
data.classes
# Out:
# ['3', '7']

# %%
labels = [('3' if '/3/' in str(x) else '7') for x in fn_paths]
labels[:5]
# Out:
# ['3', '3', '3', '3', '3']

# %%
data = ImageDataBunch.from_lists(path, fn_paths, labels=labels, ds_tfms=tfms, size=24)
data.classes
# Out:
# ['3', '7']
