# %%
# %matplotlib inline
from fastai.basics import *

# %% [markdown]
# ## MNIST SGD

# %% [markdown]
# Get the 'pickled' MNIST dataset from http://deeplearning.net/data/mnist/mnist.pkl.gz. We're going to treat it as a standard flat dataset with fully connected layers, rather than using a CNN.

# %%
# !pwd
# Out:
# /home/jupyter/tutorials/fastai/course-v3/nbs/dl1

# %%
path = Path('data/mnist')

# %%
path.ls()
# Out:
# [PosixPath('data/mnist/mnist.pkl')]

# %%
with gzip.open(path/'mnist.pkl.gz', 'rb') as f:
    ((x_train, y_train), (x_valid, y_valid), _) = pickle.load(f, encoding='latin-1')

# %%
plt.imshow(x_train[0].reshape((28,28)), cmap="gray")
x_train.shape
# Out:
# (50000, 784)

# %%
tt = torch.tensor([[1,2], [3,4], [5,6]]); tt.shape
# Out:
# torch.Size([3, 2])

# %%
x_train,y_train,x_valid,y_valid = map(torch.tensor, (x_train,y_train,x_valid,y_valid))
n,c = x_train.shape
x_train.shape, y_train.min(), y_train.max()
# Out:
# (torch.Size([50000, 784]), tensor(0), tensor(9))

# %% [markdown]
# In lesson2-sgd we did these things ourselves:
#
# ```python
# x = torch.ones(n,2)
# def mse(y_hat, y): return ((y_hat-y)**2).mean()
# y_hat = x@a
# ```
#
# Now instead we'll use PyTorch's functions to do it for us, and also to handle mini-batches (which we didn't do last time, since our dataset was so small).

# %%
TensorDataset?

# %%
bs=64
train_ds = TensorDataset(x_train, y_train)
valid_ds = TensorDataset(x_valid, y_valid)
data = DataBunch.create(train_ds, valid_ds, bs=bs)

# %%
x,y = next(iter(data.train_dl))
x.shape,y.shape
# Out:
# (torch.Size([64, 784]), torch.Size([64]))

# %%
class Mnist_Logistic(nn.Module):
    def __init__(self):
        super().__init__()
        self.lin = nn.Linear(784, 10, bias=True)

    def forward(self, xb): return self.lin(xb)

# %%
model = Mnist_Logistic().cuda()

# %%
model
# Out:
# Mnist_Logistic(
#   (lin): Linear(in_features=784, out_features=10, bias=True)
# )

# %%
model.lin
# Out:
# Linear(in_features=784, out_features=10, bias=True)

# %%
model(x).shape
# Out:
# torch.Size([64, 10])

# %%
[p.shape for p in model.parameters()]
# Out:
# [torch.Size([10, 784]), torch.Size([10])]

# %%
[p for p in model.parameters()]
# Out:
# [Parameter containing:
#  tensor([[ 0.0184, -0.0058,  0.0217,  ...,  0.0320, -0.0122, -0.0050],
#          [ 0.0023,  0.0254, -0.0313,  ...,  0.0020,  0.0092,  0.0086],
#          [-0.0130, -0.0279, -0.0143,  ...,  0.0163,  0.0128,  0.0272],
#          ...,
#          [-0.0232, -0.0293, -0.0037,  ...,  0.0134,  0.0239, -0.0024],
#          [ 0.0284,  0.0156, -0.0099,  ..., -0.0036,  0.0345,  0.0130],
#          [ 0.0134, -0.0050,  0.0182,  ..., -0.0309,  0.0058,  0.0038]],
#         device='cuda:0', requires_grad=True), Parameter containing:
#  tensor([ 0.0023, -0.0288,  0.0203,  0.0125,  0.0049,  0.0181,  0.0312,  0.0128,
#           0.0206,  0.0282], device='cuda:0', requires_grad=True)]

# %%
lr=2e-2

# %%
loss_func = nn.CrossEntropyLoss()

# %%
def update(x,y,lr):
    wd = 1e-5
    y_hat = model(x)
    # weight decay
    w2 = 0.
    for p in model.parameters(): w2 += (p**2).sum()
    # add to regular loss
    loss = loss_func(y_hat, y) + w2*wd
    loss.backward()
    with torch.no_grad():
        for p in model.parameters():
            p.sub_(lr * p.grad)
            p.grad.zero_()
    return loss.item()

# %%
losses = [update(x,y,lr) for x,y in data.train_dl]

# %%
plt.plot(losses);

# %%
class Mnist_NN(nn.Module):
    def __init__(self):
        super().__init__()
        self.lin1 = nn.Linear(784, 50, bias=True)
        self.lin2 = nn.Linear(50, 10, bias=True)

    def forward(self, xb):
        x = self.lin1(xb)
        x = F.relu(x)
        return self.lin2(x)

# %%
model = Mnist_NN().cuda()

# %%
losses = [update(x,y,lr) for x,y in data.train_dl]

# %%
plt.plot(losses);

# %%
model = Mnist_NN().cuda()

# %%
optim.Adam.step??

# %%
def update(x,y,lr):
    opt = optim.Adam(model.parameters(), lr)
    y_hat = model(x)
    loss = loss_func(y_hat, y)
    loss.backward()
    opt.step()
    opt.zero_grad()
    return loss.item()

# %%
losses = [update(x,y,1e-3) for x,y in data.train_dl]

# %%
plt.plot(losses);

# %%
Learner()

# %%
learn = Learner(data, Mnist_NN(), loss_func=loss_func, metrics=accuracy)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(1, 1e-2)
# Out:
# Total time: 00:03
# epoch  train_loss  valid_loss  accuracy
# 1      0.148536    0.135789    0.960800  (00:03)

# %%
learn.recorder.plot_lr(show_moms=True)

# %%
learn.recorder.plot_losses()

# %% [markdown]
# ## fin
